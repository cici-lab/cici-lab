# %% [markdown]
# <a href="https://colab.research.google.com/github/cici-lab/cici-lab/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-8059kklv
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-8059kklv
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.2.25)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x).relu()
    # 第一个残差块: h1 + linear2(relu(h1))
    h2 = h1 + self.linear2(h1)
    h2 = h2.relu()
    # 第二个残差块: h2 + linear3(relu(h2))
    h3 = h2 + self.linear3(h2)
    h3 = h3.relu()
    # 输出层
    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.581375, train error 62.97,  val loss 1.620423, percent error 63.80
# Epoch     1, train loss 1.284403, train error 47.35,  val loss 1.410451, percent error 55.40
# Epoch     2, train loss 1.073999, train error 38.60,  val loss 1.280165, percent error 51.30
# Epoch     3, train loss 0.885267, train error 33.35,  val loss 1.204523, percent error 48.00
# Epoch     4, train loss 0.797939, train error 29.00,  val loss 1.184905, percent error 44.40
# Epoch     5, train loss 0.678143, train error 24.35,  val loss 1.149138, percent error 43.00
# Epoch     6, train loss 0.553577, train error 19.55,  val loss 1.128440, percent error 41.60
# Epoch     7, train loss 0.487204, train error 17.03,  val loss 1.137302, percent error 41.20
# Epoch     8, train loss 0.426411, train error 15.10,  val loss 1.135378, percent error 40.40
# Epoch     9, train loss 0.426556, train error 15.68,  val loss 1.266780, percent error 40.90
# Epoch    10, train loss 0.316576, train error 10.68,  val loss 1.160712, percent error 40.00
# Epoch    11, train loss 0.320074, train error 10.80,  val loss 1.375412, percent error 40.10
# Epoch    12, train loss 0.263758, train error 8.68,  val loss 1.384555, percent error 41.10
# Epoch    13, train loss 0.194503, train error 5.57,  val loss 1.355908, percent error 38.90
# Epoch    14, train loss 0.172499, train error 5.05,  val loss 1.322253, percent error 38.20
# Epoch    15, train loss 0.191474, train error 6.57,  val loss 1.427874, percent error 39.00
# Epoch    16, train loss 0.189688, train error 5.90,  val loss 1.566979, percent error 39.50
# Epoch    17, train loss 0.155579, train error 5.10,  val loss 1.570676, percent error 38.50
# Epoch    18, train loss 0.156961, train error 5.30,  val loss 1.565509, percent error 37.70
# Epoch    19, train loss 0.102778, train error 3.20,  val loss 1.584739, percent error 38.10
# Epoch    20, train loss 0.028964, train error 0.10,  val loss 1.450236, percent error 34.60
# Epoch    21, train loss 0.016219, train error 0.05,  val loss 1.498359, percent error 36.30
# Epoch    22, train loss 0.010738, train error 0.00,  val loss 1.499012, percent error 35.20
# Epoch    23, train loss 0.008966, train error 0.00,  val loss 1.534981, percent error 35.60
# Epoch    24, train loss 0.007869, train error 0.00,  val loss 1.546379, percent error 35.70
# Epoch    25, train loss 0.007024, train error 0.00,  val loss 1.562741, percent error 35.10
# Epoch    26, train loss 0.006378, train error 0.00,  val loss 1.583580, percent error 35.10
# Epoch    27, train loss 0.005838, train error 0.00,  val loss 1.599823, percent error 35.50
# Epoch    28, train loss 0.005430, train error 0.00,  val loss 1.611951, percent error 35.30
# Epoch    29, train loss 0.005023, train error 0.00,  val loss 1.627638, percent error 35.20
# Epoch    30, train loss 0.004701, train error 0.00,  val loss 1.637283, percent error 34.90
# Epoch    31, train loss 0.004420, train error 0.00,  val loss 1.650050, percent error 35.20
# Epoch    32, train loss 0.004159, train error 0.00,  val loss 1.659538, percent error 35.10
# Epoch    33, train loss 0.003924, train error 0.00,  val loss 1.671458, percent error 35.40
# Epoch    34, train loss 0.003730, train error 0.00,  val loss 1.681588, percent error 35.00
# Epoch    35, train loss 0.003559, train error 0.00,  val loss 1.689833, percent error 35.30
# Epoch    36, train loss 0.003402, train error 0.00,  val loss 1.702653, percent error 35.00
# Epoch    37, train loss 0.003239, train error 0.00,  val loss 1.706804, percent error 35.10
# Epoch    38, train loss 0.003103, train error 0.00,  val loss 1.716006, percent error 35.00
# Epoch    39, train loss 0.002976, train error 0.00,  val loss 1.724120, percent error 34.90
# Epoch    40, train loss 0.002914, train error 0.00,  val loss 1.728160, percent error 35.00
# Epoch    41, train loss 0.002858, train error 0.00,  val loss 1.732891, percent error 35.00
# Epoch    42, train loss 0.002805, train error 0.00,  val loss 1.736631, percent error 35.00
# Epoch    43, train loss 0.002754, train error 0.00,  val loss 1.739614, percent error 35.00
# Epoch    44, train loss 0.002702, train error 0.00,  val loss 1.743081, percent error 34.90
# Epoch    45, train loss 0.002654, train error 0.00,  val loss 1.748158, percent error 34.90
# Epoch    46, train loss 0.002608, train error 0.00,  val loss 1.750772, percent error 35.00
# Epoch    47, train loss 0.002563, train error 0.00,  val loss 1.755242, percent error 35.00
# Epoch    48, train loss 0.002519, train error 0.00,  val loss 1.758078, percent error 34.90
# Epoch    49, train loss 0.002477, train error 0.00,  val loss 1.761847, percent error 34.70
# Epoch    50, train loss 0.002437, train error 0.00,  val loss 1.764733, percent error 35.00
# Epoch    51, train loss 0.002398, train error 0.00,  val loss 1.768672, percent error 34.80
# Epoch    52, train loss 0.002359, train error 0.00,  val loss 1.772290, percent error 34.90
# Epoch    53, train loss 0.002322, train error 0.00,  val loss 1.774424, percent error 34.80
# Epoch    54, train loss 0.002286, train error 0.00,  val loss 1.779135, percent error 34.80
# Epoch    55, train loss 0.002252, train error 0.00,  val loss 1.781911, percent error 34.80
# Epoch    56, train loss 0.002218, train error 0.00,  val loss 1.784593, percent error 34.80
# Epoch    57, train loss 0.002185, train error 0.00,  val loss 1.787283, percent error 34.70
# Epoch    58, train loss 0.002153, train error 0.00,  val loss 1.791178, percent error 34.60
# Epoch    59, train loss 0.002122, train error 0.00,  val loss 1.794067, percent error 34.70
# Epoch    60, train loss 0.002107, train error 0.00,  val loss 1.795390, percent error 34.60
# Epoch    61, train loss 0.002091, train error 0.00,  val loss 1.796417, percent error 34.60
# Epoch    62, train loss 0.002077, train error 0.00,  val loss 1.797973, percent error 34.60
# Epoch    63, train loss 0.002062, train error 0.00,  val loss 1.799467, percent error 34.60
# Epoch    64, train loss 0.002048, train error 0.00,  val loss 1.801132, percent error 34.60
# Epoch    65, train loss 0.002034, train error 0.00,  val loss 1.802440, percent error 34.60
# Epoch    66, train loss 0.002020, train error 0.00,  val loss 1.804073, percent error 34.60
# Epoch    67, train loss 0.002006, train error 0.00,  val loss 1.805274, percent error 34.60
# Epoch    68, train loss 0.001993, train error 0.00,  val loss 1.806528, percent error 34.60
# Epoch    69, train loss 0.001980, train error 0.00,  val loss 1.808211, percent error 34.50
# Epoch    70, train loss 0.001967, train error 0.00,  val loss 1.809145, percent error 34.50
# Epoch    71, train loss 0.001954, train error 0.00,  val loss 1.810636, percent error 34.60
# Epoch    72, train loss 0.001941, train error 0.00,  val loss 1.811784, percent error 34.50
# Epoch    73, train loss 0.001928, train error 0.00,  val loss 1.813682, percent error 34.50
# Epoch    74, train loss 0.001915, train error 0.00,  val loss 1.814870, percent error 34.50
# Epoch    75, train loss 0.001903, train error 0.00,  val loss 1.816319, percent error 34.50
# Epoch    76, train loss 0.001891, train error 0.00,  val loss 1.817628, percent error 34.50
# Epoch    77, train loss 0.001879, train error 0.00,  val loss 1.818969, percent error 34.50
# Epoch    78, train loss 0.001867, train error 0.00,  val loss 1.820050, percent error 34.50
# Epoch    79, train loss 0.001856, train error 0.00,  val loss 1.821540, percent error 34.50
# Epoch    80, train loss 0.001850, train error 0.00,  val loss 1.822054, percent error 34.50
# Epoch    81, train loss 0.001844, train error 0.00,  val loss 1.822734, percent error 34.50
# Epoch    82, train loss 0.001838, train error 0.00,  val loss 1.823385, percent error 34.50
# Epoch    83, train loss 0.001832, train error 0.00,  val loss 1.824069, percent error 34.50
# Epoch    84, train loss 0.001827, train error 0.00,  val loss 1.824764, percent error 34.50
# Epoch    85, train loss 0.001821, train error 0.00,  val loss 1.825341, percent error 34.50
# Epoch    86, train loss 0.001815, train error 0.00,  val loss 1.826027, percent error 34.50
# Epoch    87, train loss 0.001810, train error 0.00,  val loss 1.826448, percent error 34.50
# Epoch    88, train loss 0.001804, train error 0.00,  val loss 1.827103, percent error 34.50
# Epoch    89, train loss 0.001799, train error 0.00,  val loss 1.827995, percent error 34.50
# Epoch    90, train loss 0.001794, train error 0.00,  val loss 1.828451, percent error 34.50
# Epoch    91, train loss 0.001788, train error 0.00,  val loss 1.829128, percent error 34.50
# Epoch    92, train loss 0.001783, train error 0.00,  val loss 1.829663, percent error 34.50
# Epoch    93, train loss 0.001777, train error 0.00,  val loss 1.830495, percent error 34.50
# Epoch    94, train loss 0.001772, train error 0.00,  val loss 1.831014, percent error 34.50
# Epoch    95, train loss 0.001767, train error 0.00,  val loss 1.831609, percent error 34.50
# Epoch    96, train loss 0.001761, train error 0.00,  val loss 1.832245, percent error 34.50
# Epoch    97, train loss 0.001756, train error 0.00,  val loss 1.832937, percent error 34.60
# Epoch    98, train loss 0.001751, train error 0.00,  val loss 1.833548, percent error 34.50
# Epoch    99, train loss 0.001746, train error 0.00,  val loss 1.834118, percent error 34.40

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
